# %%
## Analysis improvements

- I
did
not answer
due
to
time: which
organizations
have
the
highest - rated
courses, and are
there
subject
areas
they
're not covering?
- Graphs
could
be
improved
with more detailed annotations, legends, grouping.

## Notes

- The
requirements
mentioned
seaborn and matplotlib, I
barely
used
seaborn and mostly
used
plotly.express.As
this
material
was
covered in the
course, I
assumed
it
was
ok
to
use
it as a
substitute.

## Review notes
Peer:
- White
background
- Rating
like
4.88
doesn
't make sense
- Pie
chart
first
- pip
freeze > requirements.txt
- Black
formatter -> might
check
out
- `fig1`
rename
- Download
Kaggle
datasets
using
`subprocess.run("kaggle datasets download -d siddharthm1698/coursera-course-dataset", shell=True, check=True)`.This
removes
the
need
to
commit
datasets
to
GitHub.

JTL:
- Narrow
sample
of
data
because
of
filtering, affects
conclusions
- Would
need
statistical
tests
- Give
evidence
why
filtering
Data
Science
course is a
good
approach
- Functions in the
notebook -> move
to
helpers.py
- IDE
workflow, univariant
analysis, bi - variant, multivariant -> in what
order
we
present
data.Continous
workflow.
- Pie
charts - pie
charts
are
opinionated, may
be
frowned
upon.
- Plotly.express and github - add
PDF
file
to
be
able
to
see
all
visualizations
- Data - WHEN is the
course
released? Matters a lot.Need to be careful about our assumptions, consider caveats.
